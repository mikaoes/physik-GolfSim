# %%
import src.winkel
import src.gwkraefte
import math

# %%
winkel = 45
speed = 100 # geschwindigkeit in m/s

# %%
print(src.winkel.vx(speed, winkel))
print(src.winkel.vy(speed, winkel))
# Out:
# 70.71
# 70.71

# %%
vy = src.winkel.vy(speed, winkel)
vx = src.winkel.vx(speed, winkel)

#for i in range(1, 11):
#    print(i * vy - 0.5 * 9.81 * i**2)
i = 1
while (i * vy - 0.5 * 9.81 * i**2) > 0:
    i += 0.01
print(i)

print(vx * i)
# Out:
# 14.419999999999737
# 1019.6381999999813
# Bad pipe message: %s [b".\xde\xe7'\xdb\xff\x0b\xbc\r\xbe\xa5$& \xc4{\x0fK J4\xdf\x15\x8a\xf0\xfc\xa1\x08\x86", b'M\x8f\x9c\xbe\xde\x1d\x83P\xff\xaeT\xb6\xf1\xb7\x8c\xa6\xd4S\xed\xd2\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03', b'\x08\x07\x08\x08\x08', b'\n\x08\x0b\x08\x04\x08\x05\x08']
# Bad pipe message: %s [b'\x01\x05\x01\x06\x01']
# Bad pipe message: %s [b"\xd1\x8e\x06\xc2\xcd0|\xbb\xac\xc9\xcb\x9a\xa4^#\x05\xee\x14\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00"]
# ...

# %%
print((speed * speed) / 9.81 * math.sin(math.radians(2 * winkel)))
# Out:
# 1019.367991845056
