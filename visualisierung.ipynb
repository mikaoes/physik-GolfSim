# %%
import idealeParameter
# Out:
# (45, 19)
# 355.0371999999943

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(idealeParameter.weite, square=False, cmap="YlGnBu")
plt.show()

# %%
import src.winkel

speed = 60
winkel = 45

vy = src.winkel.vy(speed, winkel)
vx = src.winkel.vx(speed, winkel)

i = 1
while (i * vy - 0.5 * 9.81 * i**2) > 0:
    i += 0.01

l = vx * i

print(f"Ball fliegt {l:.2f}m weit bei {speed}m/s und {winkel}° Winkel.")
# Out:
# Ball fliegt 367.44m weit bei 60m/s und 45° Winkel.
